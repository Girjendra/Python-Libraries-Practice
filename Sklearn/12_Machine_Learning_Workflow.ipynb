# %% [markdown]
# ## **Full Machine Learning Workflow (Step-by-Step)**

# %% [markdown]
# ### **1. Problem Definition**
# * What are you solving?
# * Example:
#     * Predict diabetes (0 / 1)
#
# ### **2. Data Collection**
# * Sources:
#     * CSV
#     * Kaggle
#     * APIs
# ```bash
# pd.read_csv()
# ```
#
# ### **3. Data Preprocessing**
# * Clean data
#     * Handle missing values
#     * Encode categorical data
#     * Feature scaling
# ```bash
# StandardScaler()
# LabelEncoder()
# SimpleImputer()
# ```
#
# #### 4. Feature Engineering
# * Improve input features
#     * Create new features
#     * Remove useless features
#
# #### **5. Train-Test Split**
# ```bash
# train_test_split(X, y, test_size=0.2)
# ```
#
# #### **6. Model Selection**
# * Choose model
#     * Logistic Regression
#     * SVM
#     * Random Forest
#
# #### **7. Model Training**
# ```bash
# model.fit(X_train, y_train)
# ```
#
# #### **8. Prediction**
# ```bash
# y_pred = model.predict(X_test)
# ```
#
# #### **9. Model Evaluation**
# * Check performance
#     * accuracy_score()
#     * confusion_matrix()
#
# #### **10. Hyperparameter Tuning**
# * GridSearchCV()
# * RandomizedSearchCV()
#
# #### **11. Pipeline (BEST PRACTICE)**
# ```bash
# Pipeline([
#     ('scaler', StandardScaler()),
#     ('model', SVC())
# ])
# ```
#
# #### **12. Save Model**
# ```bash
# pickle.dump(model, open('model.sav','wb'))
# ```
#
# #### **13. Deployment**
# * Using:
#     * Streamlit
#     * Flask
#
# #### **14. Testing & Improvement**
# * Improve accuracy
#     * More data
#     * Better features
#     * Try new models
